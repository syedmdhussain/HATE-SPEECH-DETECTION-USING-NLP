# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmdhussain/HATE-SPEECH-DETECTION-USING-NLP/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pickle
import sys
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.stem.porter import *

# %%
#https://raw.githubusercontent.com/t-davidson/hate-speech-and-offensive-language/master/data/labeled_data.csv
df = pd.read_csv("https://raw.githubusercontent.com/t-davidson/hate-speech-and-offensive-language/master/data/labeled_data.csv")
df
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither',
#        'class', 'tweet'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'], axis = 1)
# Out:
#        count  hate_speech  offensive_language  neither  class  \
# 0          3            0                   0        3      2
# 1          3            0                   3        0      1
# 2          3            0                   3        0      1
# 3          3            0                   2        1      1
# 4          6            0                   6        0      1
# ...      ...          ...                 ...      ...    ...
# 24778      3            0                   2        1      1
# 24779      3            0                   1        2      2
# 24780      3            0                   3        0      1
# 24781      6            0                   6        0      1
# 24782      3            0                   0        3      2
#
#                                                    tweet
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# ...

# %% [markdown]
# We will mostly be working with the class and tweet column

# %%
df.isnull()
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           False  False        False               False    False  False
# 1           False  False        False               False    False  False
# 2           False  False        False               False    False  False
# 3           False  False        False               False    False  False
# 4           False  False        False               False    False  False
# ...           ...    ...          ...                 ...      ...    ...
# 24778       False  False        False               False    False  False
# 24779       False  False        False               False    False  False
# 24780       False  False        False               False    False  False
# 24781       False  False        False               False    False  False
# 24782       False  False        False               False    False  False
#
#        tweet
# 0      False
# 1      False
# 2      False
# 3      False
# ...

# %%
df['class'].mask(df['class'] == 0, 1, inplace=True)

# %%
df['class'] == 0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24778    False
# 24779    False
# 24780    False
# 24781    False
# 24782    False
# Name: class, Length: 24783, dtype: bool

# %%
df.nunique()
# Out:
# Unnamed: 0            24783
# count                     5
# hate_speech               8
# offensive_language       10
# neither                  10
# class                     2
# tweet                 24783
# dtype: int64

# %%
df['class'].hist()

# %% [markdown]
# we see that the dataset is not balanced

# %%
df['class'].value_counts()
# Out:
# 1    20620
# 2     4163
# Name: class, dtype: int64

# %%
df_0_class = df[df['class']==1]
df_1_class = df[df['class']==2]
df_1_class_oversampled = df_1_class.sample(df_0_class.shape[0])
df = pd.concat([df_0_class,df_1_class_oversampled], axis=0)

# %%
df['class'].value_counts()
# Out:
# Series([], Name: class, dtype: int64)

# %%
# !pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import imblearn
print(imblearn.__version__)
# Out:
# 0.8.1

# %%
from imblearn.over_sampling import SMOTE


# Resample the minority class. You can change the strategy to 'auto' if you are not sure.
sm = SMOTE(sampling_strategy='auto', random_state=7)

# Fit the model to generate the data.
oversampled_trainX, oversampled_trainY = sm.fit_resample(df.drop('class', axis=1), df['class'])
oversampled_train = pd.concat([pd.DataFrame(oversampled_trainY), pd.DataFrame(oversampled_trainX)], axis=1)
oversampled_train.columns = normalized_df.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-975545e3ea52> in <module>()
#       6
#       7 # Fit the model to generate the data.
# ----> 8 oversampled_trainX, oversampled_trainY = sm.fit_resample(df.drop('class', axis=1), df['class'])
#       9 oversampled_train = pd.concat([pd.DataFrame(oversampled_trainY), pd.DataFrame(oversampled_trainX)], axis=1)
#      10 oversampled_train.columns = normalized_df.columns
#
# /usr/local/lib/python3.7/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# /usr/local/lib/python3.7/dist-packages/imblearn/base.py in _check_X_y(self, X, y, accept_sparse)
# ...
